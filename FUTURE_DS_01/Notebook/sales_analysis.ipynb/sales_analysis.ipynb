# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
import pandas as pd

df = pd.read_csv(
    r'C:\Users\Malin\OneDrive\Desktop\FUTURE_DS_01\Dataset\Sample - Superstore.csv',
    encoding='latin1'
)

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()

monthly_sales.plot(figsize=(12,6))

plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')

plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar', figsize=(12,6))

plt.title('Top 10 Selling Products')
plt.xlabel('Products')
plt.ylabel('Sales')

plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='pie', autopct='%1.1f%%', figsize=(7,7))

plt.title('Category Sales Distribution')
plt.ylabel('')

plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

plt.figure(figsize=(8,5))

sns.barplot(x=region_sales.index, y=region_sales.values)

plt.title('Regional Sales Performance')
plt.xlabel('Region')
plt.ylabel('Sales')

plt.show()

# %%
profit_analysis = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)

print(profit_analysis)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
print("Business Insights")
print("-------------------")

print("1. Technology category generated the highest revenue.")
print("2. West region achieved the strongest sales performance.")
print("3. Some products contribute major revenue.")
print("4. Revenue trends show growth in several months.")
print("5. High-performing categories can be targeted for future growth.")
# Out:
# Business Insights
# -------------------
# 1. Technology category generated the highest revenue.
# 2. West region achieved the strongest sales performance.
# 3. Some products contribute major revenue.
# 4. Revenue trends show growth in several months.
# 5. High-performing categories can be targeted for future growth.

# %%
import matplotlib.pyplot as plt

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Malin\OneDrive\Desktop\FUTURE_DS_01\Notebook\sales_analysis.ipynb

# %%
os.listdir()
# Out:
# ['sales_analysis.ipynb']

# %%
import os

os.makedirs('../images', exist_ok=True)

# %%
plt.savefig('../images/chart_name.png', bbox_inches='tight')

# %%
import pandas as pd

df = pd.read_csv(
    r'C:\Users\Malin\OneDrive\Desktop\FUTURE_DS_01\Dataset\Sample - Superstore.csv',
    encoding='latin1'
)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))

sns.countplot(x='Category', data=df)

plt.title('Category Distribution')

plt.savefig('../images/category_chart.png', bbox_inches='tight')

plt.show()

# %%
encoding='latin1'

# %%
import os

print(os.getcwd())
print(os.listdir('../'))
# Out:
# c:\Users\Malin\OneDrive\Desktop\FUTURE_DS_01\Notebook\sales_analysis.ipynb
# ['images', 'sales_analysis.ipynb']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.makedirs('images', exist_ok=True)

plt.figure(figsize=(8,5))

sns.countplot(x='Category', data=df)

plt.title('Category Distribution')

plt.savefig('images/category_chart.png', bbox_inches='tight')

print("Chart saved successfully!")

plt.show()
# Out:
# Chart saved successfully!
